# %% [markdown]
# # Task 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("financial_data_csv.csv")

# %%
df
# Out:
#      Company  Year  Total Revenue    Net Income  Total Assets  \
# 0  Microsoft  2024   2.451220e+11  8.813600e+10  5.121630e+11
# 1  Microsoft  2023   2.119150e+11  7.236100e+10  4.119760e+11
# 2  Microsoft  2022   1.982700e+11  7.273800e+10  3.648400e+11
# 3      Tesla  2024   9.715000e+11  1.500000e+10  1.198520e+11
# 4      Tesla  2023   9.677300e+10  1.497400e+10  1.066180e+11
# 5      Tesla  2022   8.146200e+10  1.258300e+10  8.233800e+10
# 6      Apple  2024   3.943000e+11  1.039000e+11  3.510000e+11
# 7      Apple  2023   9.699500e+11  9.400000e+11  3.520000e+11
# 8      Apple  2022   3.365000e+11  9.980300e+10  3.370000e+11
#
#    Total Liabilities  Cash Flow from Operating Activities
# 0       2.057530e+11                         1.185480e+11
# 1       2.436860e+11                         8.758200e+10
# 2       1.982980e+11                         8.903500e+10
# 3       4.914000e+10                         1.460000e+09
# 4       4.300900e+10                         1.326000e+09
# 5       3.644000e+10                         1.472000e+09
# 6       2.870000e+10                         1.220000e+10
# 7       2.790000e+11                         1.105430e+11
# 8       2.650000e+11                         1.106430e+11

# %%
df['Revenue Growth (%)'] = df.groupby(['Company'])['Total Revenue'].pct_change() * 100
df['Net Income Growth (%)'] = df.groupby(['Company'])['Net Income'].pct_change() * 100

# %%
df
# Out:
#      Company  Year  Total Revenue    Net Income  Total Assets  \
# 0  Microsoft  2024   2.451220e+11  8.813600e+10  5.121630e+11
# 1  Microsoft  2023   2.119150e+11  7.236100e+10  4.119760e+11
# 2  Microsoft  2022   1.982700e+11  7.273800e+10  3.648400e+11
# 3      Tesla  2024   9.715000e+11  1.500000e+10  1.198520e+11
# 4      Tesla  2023   9.677300e+10  1.497400e+10  1.066180e+11
# 5      Tesla  2022   8.146200e+10  1.258300e+10  8.233800e+10
# 6      Apple  2024   3.943000e+11  1.039000e+11  3.510000e+11
# 7      Apple  2023   9.699500e+11  9.400000e+11  3.520000e+11
# 8      Apple  2022   3.365000e+11  9.980300e+10  3.370000e+11
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 0       2.057530e+11                         1.185480e+11                 NaN
# 1       2.436860e+11                         8.758200e+10          -13.547132
# 2       1.982980e+11                         8.903500e+10           -6.438902
# 3       4.914000e+10                         1.460000e+09                 NaN
# 4       4.300900e+10                         1.326000e+09          -90.038806
# 5       3.644000e+10                         1.472000e+09          -15.821562
# 6       2.870000e+10                         1.220000e+10                 NaN
# 7       2.790000e+11                         1.105430e+11          145.992899
# 8       2.650000e+11                         1.106430e+11          -65.307490
#
#    Net Income Growth (%)
# 0                    NaN
# 1             -17.898475
# 2               0.520999
# 3                    NaN
# 4              -0.173333
# 5             -15.967677
# 6                    NaN
# 7             804.716073
# 8             -89.382660

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#      Company  Year  Total Revenue    Net Income  Total Assets  \
# 0  Microsoft  2024   2.451220e+11  8.813600e+10  5.121630e+11
# 1  Microsoft  2023   2.119150e+11  7.236100e+10  4.119760e+11
# 2  Microsoft  2022   1.982700e+11  7.273800e+10  3.648400e+11
# 3      Tesla  2024   9.715000e+11  1.500000e+10  1.198520e+11
# 4      Tesla  2023   9.677300e+10  1.497400e+10  1.066180e+11
# 5      Tesla  2022   8.146200e+10  1.258300e+10  8.233800e+10
# 6      Apple  2024   3.943000e+11  1.039000e+11  3.510000e+11
# 7      Apple  2023   9.699500e+11  9.400000e+11  3.520000e+11
# 8      Apple  2022   3.365000e+11  9.980300e+10  3.370000e+11
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 0       2.057530e+11                         1.185480e+11            0.000000
# 1       2.436860e+11                         8.758200e+10          -13.547132
# 2       1.982980e+11                         8.903500e+10           -6.438902
# 3       4.914000e+10                         1.460000e+09            0.000000
# 4       4.300900e+10                         1.326000e+09          -90.038806
# 5       3.644000e+10                         1.472000e+09          -15.821562
# 6       2.870000e+10                         1.220000e+10            0.000000
# 7       2.790000e+11                         1.105430e+11          145.992899
# 8       2.650000e+11                         1.106430e+11          -65.307490
#
#    Net Income Growth (%)
# 0               0.000000
# 1             -17.898475
# 2               0.520999
# 3               0.000000
# 4              -0.173333
# 5             -15.967677
# 6               0.000000
# 7             804.716073
# 8             -89.382660

# %%
summary = df.groupby('Company').agg({
    'Revenue Growth (%)': 'mean',
    'Net Income Growth (%)': 'mean'
}).reset_index()
summary
# Out:
#      Company  Revenue Growth (%)  Net Income Growth (%)
# 0      Apple           26.895136             238.444471
# 1  Microsoft           -6.662011              -5.792492
# 2      Tesla          -35.286789              -5.380337
